# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import shape, Polygon, MultiPolygon, mapping
from shapely.ops import unary_union
import folium
from folium import plugins
import branca.colormap as cm

import warnings
warnings.filterwarnings("ignore")

# %%
def simplify_for_web(gdf_wgs84: gpd.GeoDataFrame,
                     tol_m: float = 250,
                     min_area_m2: float = 0) -> gpd.GeoDataFrame:
    """
    Упрощает геометрии в метрах и возвращает в WGS84.
    tol_m — допуск упрощения в метрах (100–500 м обычно ок).
    min_area_m2 — минимальная площадь объектов (м²), мелочь можно отфильтровать.
    """
    g = gdf_wgs84.copy()
    g = g.to_crs(3857)               # в метры (псевдомеркатор)
    g["geometry"] = g.geometry.buffer(0)
    g["geometry"] = g.geometry.simplify(tol_m, preserve_topology=True)
    if min_area_m2 and min_area_m2 > 0:
        g["_area_m2"] = g.geometry.area
        g = g[g["_area_m2"] >= min_area_m2].drop(columns="_area_m2")
    g = g.to_crs(4326)               # обратно в WGS84 для веб‑карт
    g["geometry"] = g.geometry.buffer(0)
    g = g[~g.geometry.is_empty & g.geometry.notna()]
    return g


def print_map(data, 
              title, 
              save_df=False, 
              region='Сахалинская область', 
              GPKG_PATH='../data/municipal_districts_poly_edit.gpkg', 
              VALUE_COL='value',
              custom_step=False,
              step_start=0, step_end=100,
              color_to='#0030C0'):
    ID_COL = 'territory_id'
    DICT_XLSX_PATH = '../data/districts.xlsx'
    NAME_COL = 'municipal_district_name_short'

    assert ID_COL in data.columns and VALUE_COL in data.columns, 'Отсутствуют необходимые столбцы'

    gdf = gpd.read_file(GPKG_PATH)
    gdf = gdf[gdf['year_to'] == 9999].copy()

    # Если у GeoDataFrame не задан CRS — предполагаем WGS84
    if gdf.crs is None:
        gdf.set_crs(epsg=4326, inplace=True)
    else:
        gdf = gdf.to_crs(epsg=4326)

    # Привести ключ к единому типу (числовой). Удалим пробелы, затем to_numeric→Int64.
    for df_ in (data, gdf):
        df_[ID_COL] = pd.to_numeric(df_[ID_COL].astype(str).str.strip(), errors='coerce').astype('Int64')

    gdf = gdf.merge(data[[ID_COL, VALUE_COL]], on=ID_COL, how='left', validate='m:1')

    gdf_web = simplify_for_web(gdf, tol_m=250, min_area_m2=0)

    try:
        dict_df = pd.read_excel(DICT_XLSX_PATH)
        dict_df[ID_COL] = pd.to_numeric(dict_df[ID_COL].astype(str).str.strip(), errors='coerce').astype('Int64')
        cols = [ID_COL]

        for c in ['region_code', 'region_name', 'municipal_district_name_short', 'municipal_district_name']:
            if c in dict_df.columns: 
                cols.append(c)

        dict_slim = dict_df[cols].drop_duplicates(subset=[ID_COL])
        gdf_web = gdf_web.merge(dict_slim, on=ID_COL, how='left')
    except Exception as e:
        print("Не удалось добавить названия из Excel:", e)

        
    gdf_region = gdf_web[gdf_web['region_name'] == region].copy()

    center = [gdf_region.geometry.unary_union.centroid.y, gdf_region.geometry.unary_union.centroid.x]
    m_region = folium.Map(location=center, zoom_start=5, tiles='CartoDB positron', control_scale=True)

    vmin, vmax = gdf_region[VALUE_COL].min(), gdf_region[VALUE_COL].max()

    if custom_step:
        vmin = step_start
        vmax = step_end

    colormap_reg = cm.LinearColormap(
        colors=["#D7D7D7", color_to],
        vmin=vmin, vmax=vmax
    ).to_step(n=3)
    colormap_reg.caption = f"{title}"


    def style_fn_reg(feat):
        val = feat['properties'].get(VALUE_COL, None)
        color = colormap_reg(val) if val is not None else '#cccccc'
        return {'fillColor': color, 'color': '#333333', 'weight': 0.7, 'fillOpacity': 0.75}


    tooltip_reg = folium.features.GeoJsonTooltip(
        fields=[NAME_COL, VALUE_COL],
        aliases=['муниципалитет', 'value'],
        localize=True
    )

    folium.GeoJson(
        data=gdf_region.to_json(),
        name=f'Регион: {region}',
        style_function=style_fn_reg,
        tooltip=tooltip_reg
    ).add_to(m_region)

    colormap_reg.add_to(m_region)
    plugins.Fullscreen().add_to(m_region)
    folium.LayerControl(collapsed=False).add_to(m_region)

    return m_region

# %% [markdown]
# ### Население

# %%
population = pd.read_csv('../final_data/territory_population.csv')
population.head()
# Out:
#    territory_id   value
# 0          1953  187027
# 1          1954    9868
# 2          1955   20975
# 3          1956   22145
# 4          1957   39675

# %%
print_map(population[population['territory_id'] != 195], 'Плотность населения', color_to="#129221")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3deeb79a3b6a804da8f5e77d268fd00 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3deeb79a3b6a804da8f5e77d268fd00&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3deeb79a3b6a804da8f5e77d268fd00 = L.map(
#                 &quot;map_a3deeb79a3b6a804da8f5e77d268fd00&quot;,
#                 {
#                     center: [48.72276909783789, 146.82874397675883],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_a3deeb79a3b6a804da8f5e77d268fd00);
#
#
#
#
#
#             var tile_layer_97e02b9dc042299d2d203276dce18022 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_97e02b9dc042299d2d203276dce18022.addTo(map_a3deeb79a3b6a804da8f5e77d268fd00);
#
#
#         function geo_json_80e515fe28c8b37141d8b5124f9d001e_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1224&quot;: case &quot;1225&quot;: case &quot;1230&quot;: case &quot;1237&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#cccccc&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1226&quot;: case &quot;1238&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#129221ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1227&quot;: case &quot;1228&quot;: case &quot;1229&quot;: case &quot;1231&quot;: case &quot;1234&quot;: case &quot;1235&quot;: case &quot;1236&quot;: case &quot;1241&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#d7d7d7ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 default:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#74b57cff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#             }
#         }
#
#         function geo_json_80e515fe28c8b37141d8b5124f9d001e_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_80e515fe28c8b37141d8b5124f9d001e = L.geoJson(null, {
#                 onEachFeature: geo_json_80e515fe28c8b37141d8b5124f9d001e_onEachFeature,
#
#                 style: geo_json_80e515fe28c8b37141d8b5124f9d001e_styler,
#             ...{
# }
#         });
#
#         function geo_json_80e515fe28c8b37141d8b5124f9d001e_add (data) {
#             geo_json_80e515fe28c8b37141d8b5124f9d001e
#                 .addData(data);
#         }
#             geo_json_80e515fe28c8b37141d8b5124f9d001e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[142.937117, 46.95497269999999], [142.9581561, 46.948637], [142.95395649999998, 46.94303059999999], [142.9591749, 46.93263459999999], [142.9441036, 46.91612810000001], [142.9611462, 46.8965369], [142.9605521, 46.8800433], [142.9494088, 46.8735177], [142.96425229999997, 46.8440349], [142.978448, 46.84525779999999], [142.97852979999996, 46.8401155], [142.96840710000004, 46.8392602], [142.96578829999999, 46.830993299999996], [142.95560369999998, 46.82773660000001], [142.9555243, 46.825250399999994], [142.9430495, 46.8253201], [142.9237271, 46.8324116], [142.91798599999998, 46.8257798], [142.92676909999997, 46.80616549999999], [142.9150826, 46.80171059999999], [142.90893740000004, 46.80462000000001], [142.9177377, 46.80886430000001], [142.9142389, 46.8144631], [142.9004892, 46.818764699999996], [142.8958781, 46

# %% [markdown]
# ### Миграция

# %%
relative_migration = pd.read_csv('./transform_data/relative_migration.csv')
relative_migration.head()
# Out:
#    Unnamed: 0  territory_id               municipal_district_name age_group  \
# 0           0          1953  городской округ город Южно-Сахалинск     Всего
# 1           1          1953  городской округ город Южно-Сахалинск     Всего
# 2           2          1953  городской округ город Южно-Сахалинск      0-14
# 3           3          1953  городской округ город Южно-Сахалинск      0-14
# 4           4          1953  городской округ город Южно-Сахалинск     15-24
#
#     gender  population  migration  migration_relative
# 0  Женщины    107500.0     -124.0           -0.115349
# 1  Мужчины    100341.0    -1212.0           -1.207881
# 2  Женщины     15401.0       -6.0           -0.038959
# 3  Мужчины     15862.0      -16.0           -0.100870
# 4  Женщины      8257.0      -32.0           -0.387550

# %%
relative_migration.describe()
# Out:
#        Unnamed: 0  territory_id     population    migration  \
# count  180.000000    180.000000     180.000000   180.000000
# mean    89.500000   1961.000000    5084.333333   -29.377778
# std     52.105662      5.113243   11953.655584   126.651113
# min      0.000000   1953.000000     317.000000 -1212.000000
# 25%     44.750000   1956.000000    1031.750000   -30.500000
# 50%     89.500000   1961.000000    1941.500000   -10.000000
# 75%    134.250000   1966.000000    4202.250000     8.000000
# max    179.000000   1969.000000  107500.000000   184.000000
#
#        migration_relative
# count          180.000000
# mean            -0.745147
# std              2.888404
# min            -16.057234
# 25%             -1.591828
# 50%             -0.424742
# 75%              0.393785
# max              9.783631

# %%
print_map(relative_migration[(relative_migration['age_group'] == 'Всего') & (relative_migration['gender'] == 'Женщины')],
        'Относительная миграция (женшины)',
        VALUE_COL='migration_relative', custom_step=True, step_start=-10, step_end=10)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2cf9841879c8a0c96e56abd944c8b50e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2cf9841879c8a0c96e56abd944c8b50e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2cf9841879c8a0c96e56abd944c8b50e = L.map(
#                 &quot;map_2cf9841879c8a0c96e56abd944c8b50e&quot;,
#                 {
#                     center: [48.72276909783789, 146.82874397675883],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_2cf9841879c8a0c96e56abd944c8b50e);
#
#
#
#
#
#             var tile_layer_e6b4d00ebbb7a991086308af7cf6a111 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e6b4d00ebbb7a991086308af7cf6a111.addTo(map_2cf9841879c8a0c96e56abd944c8b50e);
#
#
#         function geo_json_c1f5d9c4104dab33ea1d3327f73c47ce_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1224&quot;: case &quot;1227&quot;: case &quot;1228&quot;: case &quot;1229&quot;: case &quot;1231&quot;: case &quot;1233&quot;: case &quot;1234&quot;: case &quot;1235&quot;: case &quot;1236&quot;: case &quot;1238&quot;: case &quot;1241&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#7f99e6ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1225&quot;: case &quot;1230&quot;: case &quot;1237&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#cccccc&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 default:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#5576daff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#             }
#         }
#
#         function geo_json_c1f5d9c4104dab33ea1d3327f73c47ce_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_c1f5d9c4104dab33ea1d3327f73c47ce = L.geoJson(null, {
#                 onEachFeature: geo_json_c1f5d9c4104dab33ea1d3327f73c47ce_onEachFeature,
#
#                 style: geo_json_c1f5d9c4104dab33ea1d3327f73c47ce_styler,
#             ...{
# }
#         });
#
#         function geo_json_c1f5d9c4104dab33ea1d3327f73c47ce_add (data) {
#             geo_json_c1f5d9c4104dab33ea1d3327f73c47ce
#                 .addData(data);
#         }
#             geo_json_c1f5d9c4104dab33ea1d3327f73c47ce_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[142.937117, 46.95497269999999], [142.9581561, 46.948637], [142.95395649999998, 46.94303059999999], [142.9591749, 46.93263459999999], [142.9441036, 46.91612810000001], [142.9611462, 46.8965369], [142.9605521, 46.8800433], [142.9494088, 46.8735177], [142.96425229999997, 46.8440349], [142.978448, 46.84525779999999], [142.97852979999996, 46.8401155], [142.96840710000004, 46.8392602], [142.96578829999999, 46.830993299999996], [142.95560369999998, 46.82773660000001], [142.9555243, 46.825250399999994], [142.9430495, 46.8253201], [142.9237271, 46.8324116], [142.91798599999998, 46.8257798], [142.92676909999997, 46.80616549999999], [142.9150826, 46.80171059999999], [142.90893740000004, 46.80462000000001], [142.9177377, 46.80886430000001], [142.9142389, 46.8144631], [142.9004892, 46.818764699999996], [142.8958781, 46.8244231], [142.902491, 46.8336112], [142.8904511, 46.8366261], [142.8881652, 46.8292298], [142.8782084, 46.82729119999999], [142.8691774, 46.831318], [142.8824737, 46.84997], [142.8752719

# %%
print_map(relative_migration[(relative_migration['age_group'] == '15-24') & (relative_migration['gender'] == 'Женщины')],
        'Относительная миграция (Женщины, 15-24 года)',
        VALUE_COL='migration_relative', custom_step=True, step_start=-10, step_end=10)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f68ffd938bdf76143d03dae8f216fb88 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f68ffd938bdf76143d03dae8f216fb88&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f68ffd938bdf76143d03dae8f216fb88 = L.map(
#                 &quot;map_f68ffd938bdf76143d03dae8f216fb88&quot;,
#                 {
#                     center: [48.72276909783789, 146.82874397675883],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_f68ffd938bdf76143d03dae8f216fb88);
#
#
#
#
#
#             var tile_layer_63acdff7e446f2b05812a65120015783 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_63acdff7e446f2b05812a65120015783.addTo(map_f68ffd938bdf76143d03dae8f216fb88);
#
#
#         function geo_json_7f55d7d6473547fc226ab024abe48b6b_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1224&quot;: case &quot;1228&quot;: case &quot;1233&quot;: case &quot;1236&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#7f99e6ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1225&quot;: case &quot;1230&quot;: case &quot;1237&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#cccccc&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1226&quot;: case &quot;1241&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#2a53cdff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1227&quot;: case &quot;1231&quot;: case &quot;1232&quot;: case &quot;1238&quot;: case &quot;1239&quot;: case &quot;1240&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#5576daff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1229&quot;: case &quot;1234&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#aabcf3ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 default:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#d4dfffff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#             }
#         }
#
#         function geo_json_7f55d7d6473547fc226ab024abe48b6b_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_7f55d7d6473547fc226ab024abe48b6b = L.geoJson(null, {
#                 onEachFeature: geo_json_7f55d7d6473547fc226ab024abe48b6b_onEachFeature,
#
#                 style: geo_json_7f55d7d6473547fc226ab024abe48b6b_styler,
#             ...{
# }
#         });
#
#         function geo_json_7f55d7d6473547fc226ab024abe48b6b_add (data) {
#             geo_json_7f55d7d6473547fc226ab024abe48b6b
#                 .addData(data);
#         }
#             geo_json_7f55d7d6473547fc226ab024abe48b6b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[142.937117, 46.95497269999999], [142.9581561, 46.948637], [142.95395649999998, 46.94303059999999], [142.9591749, 46.93263459999999], [142.9441036, 46.91612810000001], [142.9611462, 46.8965369], [142.9605521, 46.8800433], [142.9494088, 46.8735177], [142.96425229999997, 46.8440349], [142.978448, 46.84525779999999], [142.97852979999996, 46.8401155], [142.96840710000004, 46

# %%
print_map(relative_migration[(relative_migration['age_group'] == '25-44') & (relative_migration['gender'] == 'Женщины')],
        'Относительная миграция (Женщины, 25-44 года)',
        VALUE_COL='migration_relative', custom_step=True, step_start=-10, step_end=10)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3e74c1cbc24b9ba8132269ff1232485 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3e74c1cbc24b9ba8132269ff1232485&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e3e74c1cbc24b9ba8132269ff1232485 = L.map(
#                 &quot;map_e3e74c1cbc24b9ba8132269ff1232485&quot;,
#                 {
#                     center: [48.72276909783789, 146.82874397675883],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_e3e74c1cbc24b9ba8132269ff1232485);
#
#
#
#
#
#             var tile_layer_3fcf0d6f3b5c1f1173875def87ad43e2 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3fcf0d6f3b5c1f1173875def87ad43e2.addTo(map_e3e74c1cbc24b9ba8132269ff1232485);
#
#
#         function geo_json_a15a3c8d50239700475d329f10a512a3_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1224&quot;: case &quot;1231&quot;: case &quot;1235&quot;: case &quot;1239&quot;: case &quot;1240&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#5576daff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1225&quot;: case &quot;1230&quot;: case &quot;1237&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#cccccc&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1226&quot;: case &quot;1227&quot;: case &quot;1228&quot;: case &quot;1229&quot;: case &quot;1232&quot;: case &quot;1233&quot;: case &quot;1234&quot;: case &quot;1238&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#7f99e6ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 default:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#aabcf3ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#             }
#         }
#
#         function geo_json_a15a3c8d50239700475d329f10a512a3_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_a15a3c8d50239700475d329f10a512a3 = L.geoJson(null, {
#                 onEachFeature: geo_json_a15a3c8d50239700475d329f10a512a3_onEachFeature,
#
#                 style: geo_json_a15a3c8d50239700475d329f10a512a3_styler,
#             ...{
# }
#         });
#
#         function geo_json_a15a3c8d50239700475d329f10a512a3_add (data) {
#             geo_json_a15a3c8d50239700475d329f10a512a3
#                 .addData(data);
#         }
#             geo_json_a15a3c8d50239700475d329f10a512a3_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[142.937117, 46.95497269999999], [142.9581561, 46.948637], [142.95395649999998, 46.94303059999999], [142.9591749, 46.93263459999999], [142.9441036, 46.91612810000001], [142.9611462, 46.8965369], [142.9605521, 46.8800433], [142.9494088, 46.8735177], [142.96425229999997, 46.8440349], [142.978448, 46.84525779999999], [142.97852979999996, 46.8401155], [142.96840710000004, 46.8392602], [142.96578829999999, 46.830993299999996], [142.95560369999998, 46.82773660000001], [142.9555243, 46.825250399999994], [142.9430495, 46.8253201], [142.9237271, 46.8324116], [142.91798599999998, 46.8257798], [142.92676909999997, 46.80616549999999], [142.9150826, 46.80171059999999], [142.90893740000004, 46.80462000000001], [142.9177377, 46.80886430000001], [142.9142389, 46.8144631], [142.

# %%
print_map(relative_migration[(relative_migration['age_group'] == '45-64') & (relative_migration['gender'] == 'Женщины')],
        'Относительная миграция (Женщины, 45-64 года)',
        VALUE_COL='migration_relative', custom_step=True, step_start=-10, step_end=10)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_015abf5098d72816504ab4b8868b1953 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_015abf5098d72816504ab4b8868b1953&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_015abf5098d72816504ab4b8868b1953 = L.map(
#                 &quot;map_015abf5098d72816504ab4b8868b1953&quot;,
#                 {
#                     center: [48.72276909783789, 146.82874397675883],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_015abf5098d72816504ab4b8868b1953);
#
#
#
#
#
#             var tile_layer_872ceeb678beb9a5e107292b857b1b51 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_872ceeb678beb9a5e107292b857b1b51.addTo(map_015abf5098d72816504ab4b8868b1953);
#
#
#         function geo_json_bbb8599de9963870fa1883527c7eb567_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1224&quot;: case &quot;1226&quot;: case &quot;1227&quot;: case &quot;1228&quot;: case &quot;1231&quot;: case &quot;1233&quot;: case &quot;1234&quot;: case &quot;1236&quot;: case &quot;1239&quot;: case &quot;1240&quot;: case &quot;1241&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#7f99e6ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1225&quot;: case &quot;1230&quot;: case &quot;1237&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#cccccc&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 default:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#5576daff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#             }
#         }
#
#         function geo_json_bbb8599de9963870fa1883527c7eb567_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_bbb8599de9963870fa1883527c7eb567 = L.geoJson(null, {
#                 onEachFeature: geo_json_bbb8599de9963870fa1883527c7eb567_onEachFeature,
#
#                 style: geo_json_bbb8599de9963870fa1883527c7eb567_styler,
#             ...{
# }
#         });
#
#         function geo_json_bbb8599de9963870fa1883527c7eb567_add (data) {
#             geo_json_bbb8599de9963870fa1883527c7eb567
#                 .addData(data);
#         }
#             geo_json_bbb8599de9963870fa1883527c7eb567_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[142.937117, 46.95497269999999], [142.9581561, 46.948637], [142.95395649999998, 46.94303059999999], [142.9591749, 46.93263459999999], [142.9441036, 46.91612810000001], [142.9611462, 46.8965369], [142.9605521, 46.8800433], [142.9494088, 46.8735177], [142.96425229999997, 46.8440349], [142.978448, 46.84525779999999], [142.97852979999996, 46.8401155], [142.96840710000004, 46.8392602], [142.96578829999999, 46.830993299999996], [142.95560369999998, 46.82773660000001], [142.9555243, 46.825250399999994], [142.9430495, 46.8253201], [142.9237271, 46.8324116], [142.91798599999998, 46.8257798], [142.92676909999997, 46.80616549999999], [142.9150826, 46.80171059999999], [142.90893740000004, 46.80462000000001], [142.9177377, 46.80886430000001], [142.9142389, 46.8144631], [142.9004892, 46.818764699999996], [142.8958781, 46.8244231], [142.902491, 46.8336112], [142.8904511, 46.8366261], [142.8881652, 46.8292298], [142.8782084, 46.82729119999999], [142.8691774, 46.831318], [142.8824737, 46.84997], [142.8752719

# %%
print_map(relative_migration[(relative_migration['age_group'] == 'Всего') & (relative_migration['gender'] == 'Мужчины')],
        'Относительная миграция (Мужчины)',
        VALUE_COL='migration_relative', custom_step=True, step_start=-10, step_end=10)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91aa1e99bab01f4de03faee2c19b7961 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91aa1e99bab01f4de03faee2c19b7961&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91aa1e99bab01f4de03faee2c19b7961 = L.map(
#                 &quot;map_91aa1e99bab01f4de03faee2c19b7961&quot;,
#                 {
#                     center: [48.72276909783789, 146.82874397675883],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_91aa1e99bab01f4de03faee2c19b7961);
#
#
#
#
#
#             var tile_layer_4ef1dad8a31d06310f89781d9557f6d9 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ef1dad8a31d06310f89781d9557f6d9.addTo(map_91aa1e99bab01f4de03faee2c19b7961);
#
#
#         function geo_json_21c2040981397b4724b43467e285199e_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1224&quot;: case &quot;1226&quot;: case &quot;1228&quot;: case &quot;1231&quot;: case &quot;1232&quot;: case &quot;1233&quot;: case &quot;1236&quot;: case &quot;1241&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#7f99e6ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1225&quot;: case &quot;1230&quot;: case &quot;1237&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#cccccc&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1227&quot;: case &quot;1234&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#d4dfffff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 default:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#5576daff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#             }
#         }
#
#         function geo_json_21c2040981397b4724b43467e285199e_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_21c2040981397b4724b43467e285199e = L.geoJson(null, {
#                 onEachFeature: geo_json_21c2040981397b4724b43467e285199e_onEachFeature,
#
#                 style: geo_json_21c2040981397b4724b43467e285199e_styler,
#             ...{
# }
#         });
#
#         function geo_json_21c2040981397b4724b43467e285199e_add (data) {
#             geo_json_21c2040981397b4724b43467e285199e
#                 .addData(data);
#         }
#             geo_json_21c2040981397b4724b43467e285199e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[142.937117, 46.95497269999999], [142.9581561, 46.948637], [142.95395649999998, 46.94303059999999], [142.9591749, 46.93263459999999], [142.9441036, 46.91612810000001], [142.9611462, 46.8965369], [142.9605521, 46.8800433], [142.9494088, 46.8735177], [142.96425229999997, 46.8440349], [142.978448, 46.84525779999999], [142.97852979999996, 46.8401155], [142.96840710000004, 46.8392602], [142.96578829999999, 46.830993299999996], [142.95560369999998, 46.82773660000001], [142.9555243, 46.825250399999994], [142.9430495, 46.8253201], [142.9237271, 46.8324116], [142.91798599999998, 46.8257798], [142.92676909999997, 46.80616549999999], [142.9150826, 46.80171059999999], [142.90893740000004, 46.80462000000001], [142.9177377, 46.80886430000001], [142.9142389, 46.8144631], [142.9004892, 46.818764699999996], [142.8958781, 46.8244231], [142.902491,

# %%
print_map(relative_migration[(relative_migration['age_group'] == '15-24') & (relative_migration['gender'] == 'Мужчины')],
        'Относительная миграция (Мужчины, 15-24 года)',
        VALUE_COL='migration_relative', custom_step=True, step_start=-10, step_end=10)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f748b12867fb324598a7b58a8c9a958 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f748b12867fb324598a7b58a8c9a958&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f748b12867fb324598a7b58a8c9a958 = L.map(
#                 &quot;map_1f748b12867fb324598a7b58a8c9a958&quot;,
#                 {
#                     center: [48.72276909783789, 146.82874397675883],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_1f748b12867fb324598a7b58a8c9a958);
#
#
#
#
#
#             var tile_layer_31591eaee471ae6a69d5e57a07d8459d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_31591eaee471ae6a69d5e57a07d8459d.addTo(map_1f748b12867fb324598a7b58a8c9a958);
#
#
#         function geo_json_09c81141477169949f49599a05e07685_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1224&quot;: case &quot;1228&quot;: case &quot;1232&quot;: case &quot;1233&quot;: case &quot;1236&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#7f99e6ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1225&quot;: case &quot;1230&quot;: case &quot;1237&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#cccccc&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1226&quot;: case &quot;1229&quot;: case &quot;1231&quot;: case &quot;1238&quot;: case &quot;1240&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#5576daff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1227&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#aabcf3ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1234&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#d4dfffff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1235&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#0030c0ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 default:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#2a53cdff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#             }
#         }
#
#         function geo_json_09c81141477169949f49599a05e07685_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_09c81141477169949f49599a05e07685 = L.geoJson(null, {
#                 onEachFeature: geo_json_09c81141477169949f49599a05e07685_onEachFeature,
#
#                 style: geo_json_09c81141477169949f49599a05e07685_styler,
#             ...{
# }
#         });
#
#         function geo_json_09c81141477169949f49599a05e07685_add (data) {
#             geo_json_09c81141477169949f49599a05e07685
#                 .addData(data);
#         }
#             geo_json_09c81141477169949f49599a05e07685_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[142.937117, 46.95497269999999], [142.9581561, 46.948637], [142.95395649999998, 46.94303059999999], [142.9591749, 46.93263459999999], [142.9441036, 46.91612810000001], [142.9611462, 46.8965369], [142.9605521,

# %%
print_map(relative_migration[(relative_migration['age_group'] == '25-44') & (relative_migration['gender'] == 'Мужчины')],
        'Относительная миграция (Мужчины, 25-44 года)',
        VALUE_COL='migration_relative', custom_step=True, step_start=-10, step_end=10)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd744d489d963c2bff654edf815c5145 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd744d489d963c2bff654edf815c5145&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd744d489d963c2bff654edf815c5145 = L.map(
#                 &quot;map_bd744d489d963c2bff654edf815c5145&quot;,
#                 {
#                     center: [48.72276909783789, 146.82874397675883],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_bd744d489d963c2bff654edf815c5145);
#
#
#
#
#
#             var tile_layer_5f2dbb24e8e24e6fe78f1dfe2097b5cf = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5f2dbb24e8e24e6fe78f1dfe2097b5cf.addTo(map_bd744d489d963c2bff654edf815c5145);
#
#
#         function geo_json_b43f2e5615cf4e532835fc0a567f11fd_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1224&quot;: case &quot;1226&quot;: case &quot;1228&quot;: case &quot;1231&quot;: case &quot;1232&quot;: case &quot;1233&quot;: case &quot;1236&quot;: case &quot;1241&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#7f99e6ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1225&quot;: case &quot;1230&quot;: case &quot;1237&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#cccccc&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1227&quot;: case &quot;1234&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#d4dfffff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 default:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#5576daff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#             }
#         }
#
#         function geo_json_b43f2e5615cf4e532835fc0a567f11fd_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_b43f2e5615cf4e532835fc0a567f11fd = L.geoJson(null, {
#                 onEachFeature: geo_json_b43f2e5615cf4e532835fc0a567f11fd_onEachFeature,
#
#                 style: geo_json_b43f2e5615cf4e532835fc0a567f11fd_styler,
#             ...{
# }
#         });
#
#         function geo_json_b43f2e5615cf4e532835fc0a567f11fd_add (data) {
#             geo_json_b43f2e5615cf4e532835fc0a567f11fd
#                 .addData(data);
#         }
#             geo_json_b43f2e5615cf4e532835fc0a567f11fd_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[142.937117, 46.95497269999999], [142.9581561, 46.948637], [142.95395649999998, 46.94303059999999], [142.9591749, 46.93263459999999], [142.9441036, 46.91612810000001], [142.9611462, 46.8965369], [142.9605521, 46.8800433], [142.9494088, 46.8735177], [142.96425229999997, 46.8440349], [142.978448, 46.84525779999999], [142.97852979999996, 46.8401155], [142.96840710000004, 46.8392602], [142.96578829999999, 46.830993299999996], [142.95560369999998, 46.82773660000001], [142.9555243, 46.825250399999994], [142.9430495, 46.8253201], [142.9237271, 46.8324116], [142.91798599999998, 46.8257798], [142.92676909999997, 46.80616549999999], [142.9150826, 46.80171059999999], [142.90893740000004, 46.80462000000001], [142.9177377, 46.80886430000001], [142.9142389, 46.8144631], [142.9004892, 46.818764699999996], [142.8958781, 46.8244231], [142.902491,

# %%
print_map(relative_migration[(relative_migration['age_group'] == '45-64') & (relative_migration['gender'] == 'Мужчины')],
        'Относительная миграция (Мужчины, 45-64 года)',
        VALUE_COL='migration_relative', custom_step=True, step_start=-10, step_end=10)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4152e42615ff3dde0dc53e639c93fd3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4152e42615ff3dde0dc53e639c93fd3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4152e42615ff3dde0dc53e639c93fd3 = L.map(
#                 &quot;map_a4152e42615ff3dde0dc53e639c93fd3&quot;,
#                 {
#                     center: [48.72276909783789, 146.82874397675883],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_a4152e42615ff3dde0dc53e639c93fd3);
#
#
#
#
#
#             var tile_layer_3aff60f6da3a24ae37c90879777163a5 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3aff60f6da3a24ae37c90879777163a5.addTo(map_a4152e42615ff3dde0dc53e639c93fd3);
#
#
#         function geo_json_2cb42a015600c341458fb061d553ee1b_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1224&quot;: case &quot;1226&quot;: case &quot;1231&quot;: case &quot;1233&quot;: case &quot;1236&quot;: case &quot;1240&quot;: case &quot;1241&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#7f99e6ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1225&quot;: case &quot;1230&quot;: case &quot;1237&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#cccccc&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1227&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#aabcf3ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1228&quot;: case &quot;1229&quot;: case &quot;1232&quot;: case &quot;1235&quot;: case &quot;1238&quot;: case &quot;1239&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#5576daff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 default:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#d4dfffff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#             }
#         }
#
#         function geo_json_2cb42a015600c341458fb061d553ee1b_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_2cb42a015600c341458fb061d553ee1b = L.geoJson(null, {
#                 onEachFeature: geo_json_2cb42a015600c341458fb061d553ee1b_onEachFeature,
#
#                 style: geo_json_2cb42a015600c341458fb061d553ee1b_styler,
#             ...{
# }
#         });
#
#         function geo_json_2cb42a015600c341458fb061d553ee1b_add (data) {
#             geo_json_2cb42a015600c341458fb061d553ee1b
#                 .addData(data);
#         }
#             geo_json_2cb42a015600c341458fb061d553ee1b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[142.937117, 46.95497269999999], [142.9581561, 46.948637], [142.95395649999998, 46.94303059999999], [142.9591749, 46.93263459999999], [142.9441036, 46.91612810000001], [142.9611462, 46.8965369], [142.9605521, 46.8800433], [142.9494088, 46.8735177], [142.96425229999997, 46.8440349], [142.978448, 46.84525779999999], [142.97852979999996, 46.8401155], [142.96840710000004, 46.8392602], [142.96578829999999, 46.830993299999996], [142.95560369999998, 46.82773660000001], [142.9555243, 46.825250399999994], [142.9430495, 46.8253201], [142.9237271, 46.8324116], [142.

# %% [markdown]
# ### Зарплаты

# %%
salary = pd.read_csv('./transform_data/salary.csv')

# %%
salary['okved_name'].unique()
# Out:
# array(['Водоснабжение', 'Все отрасли',
#        'Гос. управление и военн. безопасность',
#        'Административная деятельность', 'Здравоохранение', 'ИТ и связь',
#        'Спорт и досуг', 'Гостиницы и общепит', 'Операции с недвижимостью',
#        'Научная и проф. деятельность', 'Финансы и страхование',
#        'Услуги ЖКХ', 'Обрабатывающие производства', 'Образование',
#        'Прочие услуги', 'Сельское хозяйство', 'Строительство', 'Торговля',
#        'Транспортировка и хранение'], dtype=object)

# %%
print_map(salary[(salary['okved_name'] == 'Все отрасли') & (salary['year'] == 2024)],
        'Все сферы зп')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c7da144495f8c1efad42f6462446cb4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c7da144495f8c1efad42f6462446cb4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c7da144495f8c1efad42f6462446cb4 = L.map(
#                 &quot;map_9c7da144495f8c1efad42f6462446cb4&quot;,
#                 {
#                     center: [48.72276909783789, 146.82874397675883],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_9c7da144495f8c1efad42f6462446cb4);
#
#
#
#
#
#             var tile_layer_d059bc5b40b172954181a5a37e7d7991 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d059bc5b40b172954181a5a37e7d7991.addTo(map_9c7da144495f8c1efad42f6462446cb4);
#
#
#         function geo_json_15853cd8f686cf13ae92011ac401d88c_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1224&quot;: case &quot;1227&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#5576daff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1225&quot;: case &quot;1230&quot;: case &quot;1237&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#cccccc&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1226&quot;: case &quot;1228&quot;: case &quot;1229&quot;: case &quot;1231&quot;: case &quot;1232&quot;: case &quot;1235&quot;: case &quot;1236&quot;: case &quot;1239&quot;: case &quot;1240&quot;: case &quot;1241&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#d4dfffff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1233&quot;: case &quot;1238&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#7f99e6ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 default:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#0030c0ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#             }
#         }
#
#         function geo_json_15853cd8f686cf13ae92011ac401d88c_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_15853cd8f686cf13ae92011ac401d88c = L.geoJson(null, {
#                 onEachFeature: geo_json_15853cd8f686cf13ae92011ac401d88c_onEachFeature,
#
#                 style: geo_json_15853cd8f686cf13ae92011ac401d88c_styler,
#             ...{
# }
#         });
#
#         function geo_json_15853cd8f686cf13ae92011ac401d88c_add (data) {
#             geo_json_15853cd8f686cf13ae92011ac401d88c
#                 .addData(data);
#         }
#             geo_json_15853cd8f686cf13ae92011ac401d88c_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[142.937117, 46.95497269999999], [142.9581561, 46.948637], [142.95395649999998, 46.94303059999999], [142.9591749, 46.93263459999999], [142.9441036, 46.91612810000001], [142.9611462, 46.8965369], [142.9605521, 46.8800433], [142.9494088, 46.8735177], [142.96425229999997, 46.8440349], [142.978448, 46.84525779999999], [142.97852979999996, 46.8401155], [142.96840710000004, 46.8392602], [142.96578829999999, 46.830993299999996], [142.95560369999998, 46.82773660000001], [142.9555243, 46.825250399999994], [142.9430495, 46.8253201], [142.9237271, 46.8324116], [142.

# %% [markdown]
# ### Траты

# %%
consumption_final = pd.read_csv('./transform_data/consumption_final.csv')

# %%
consumption_final['category'].unique()
# Out:
# array(['Продовольствие', 'Здоровье', 'Маркетплейсы',
#        'Общественное питание', 'Транспорт', 'Все категории'], dtype=object)

# %%
print_map(consumption_final[consumption_final['category'] == 'Все категории'],
        'Траты по всем категориям', VALUE_COL='consumption_percent')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c614ca1161708a54cb2af1ce18f26a3d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c614ca1161708a54cb2af1ce18f26a3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c614ca1161708a54cb2af1ce18f26a3d = L.map(
#                 &quot;map_c614ca1161708a54cb2af1ce18f26a3d&quot;,
#                 {
#                     center: [48.72276909783789, 146.82874397675883],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_c614ca1161708a54cb2af1ce18f26a3d);
#
#
#
#
#
#             var tile_layer_f541d068885cb930204272e274013a9d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f541d068885cb930204272e274013a9d.addTo(map_c614ca1161708a54cb2af1ce18f26a3d);
#
#
#         function geo_json_d651dd6344fbf51224104c2740bb5948_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1224&quot;: case &quot;1225&quot;: case &quot;1230&quot;: case &quot;1237&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#cccccc&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1226&quot;: case &quot;1229&quot;: case &quot;1235&quot;: case &quot;1238&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#7f99e6ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1227&quot;: case &quot;1239&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#aabcf3ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1228&quot;: case &quot;1232&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#2a53cdff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1231&quot;: case &quot;1233&quot;: case &quot;1236&quot;: case &quot;1241&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#5576daff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1234&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#d4dfffff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 default:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#0030c0ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#             }
#         }
#
#         function geo_json_d651dd6344fbf51224104c2740bb5948_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_d651dd6344fbf51224104c2740bb5948 = L.geoJson(null, {
#                 onEachFeature: geo_json_d651dd6344fbf51224104c2740bb5948_onEachFeature,
#
#                 style: geo_json_d651dd6344fbf51224104c2740bb5948_styler,
#             ...{
# }
#         });
#
#         function geo_json_d651dd6344fbf51224104c2740bb5948_add (data) {
#             geo_json_d651dd6344fbf51224104c2740bb5948
#                 .addData(data);
#         }
#             geo_json_d651dd6344fbf51224104c2740bb5948_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[142.937117, 46.95497269999999], [142.9581561, 46.948637], [142.95395649999998, 46.94303059999999], [142.9591749, 46.93263459999999], [142.9441036, 46.91612810000001], [142.9611462, 46.

# %%
print_map(consumption_final[consumption_final['category'] == 'Транспорт'],
        'Траты на транспорт', VALUE_COL='consumption_percent')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77c1fa90ceccb8ddbcc4c410a7766f36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77c1fa90ceccb8ddbcc4c410a7766f36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77c1fa90ceccb8ddbcc4c410a7766f36 = L.map(
#                 &quot;map_77c1fa90ceccb8ddbcc4c410a7766f36&quot;,
#                 {
#                     center: [48.72276909783789, 146.82874397675883],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_77c1fa90ceccb8ddbcc4c410a7766f36);
#
#
#
#
#
#             var tile_layer_2fb1cc006e7edbdbda1773a070cb82ea = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2fb1cc006e7edbdbda1773a070cb82ea.addTo(map_77c1fa90ceccb8ddbcc4c410a7766f36);
#
#
#         function geo_json_56a0a46095162e121edded6e66894207_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1224&quot;: case &quot;1225&quot;: case &quot;1230&quot;: case &quot;1237&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#cccccc&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1226&quot;: case &quot;1227&quot;: case &quot;1231&quot;: case &quot;1233&quot;: case &quot;1234&quot;: case &quot;1235&quot;: case &quot;1236&quot;: case &quot;1239&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#d4dfffff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1228&quot;: case &quot;1232&quot;: case &quot;1238&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#7f99e6ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1229&quot;: case &quot;1241&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#aabcf3ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 default:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#0030c0ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#             }
#         }
#
#         function geo_json_56a0a46095162e121edded6e66894207_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_56a0a46095162e121edded6e66894207 = L.geoJson(null, {
#                 onEachFeature: geo_json_56a0a46095162e121edded6e66894207_onEachFeature,
#
#                 style: geo_json_56a0a46095162e121edded6e66894207_styler,
#             ...{
# }
#         });
#
#         function geo_json_56a0a46095162e121edded6e66894207_add (data) {
#             geo_json_56a0a46095162e121edded6e66894207
#                 .addData(data);
#         }
#             geo_json_56a0a46095162e121edded6e66894207_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[142.937117, 46.95497269999999], [142.9581561, 46.948637], [142.95395649999998, 46.94303059999999], [142.9591749, 46.93263459999999], [142.9441036, 46.91612810000001], [142.9611462, 46.8965369], [142.9605521, 46.8800433], [142.9494088, 46.8735177], [142.96425229999997, 46.8440349], [142.978448, 46.84525779999999], [142.97852979999996, 46.8401155], [142.96840710000004, 46.8392602], [142.96578829999999, 46.830993299999996], [142.95560369999998, 46.82773660000001], [142.9555243, 46.825250399999994], [142.9430495, 46.8253201], [142.9237271, 46.8324116], [142.

# %%
print_map(consumption_final[consumption_final['category'] == 'Общественное питание'],
        'Траты на общественное питание', VALUE_COL='consumption_percent')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dcbfffb3dc6b57113968a170d08441b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dcbfffb3dc6b57113968a170d08441b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dcbfffb3dc6b57113968a170d08441b6 = L.map(
#                 &quot;map_dcbfffb3dc6b57113968a170d08441b6&quot;,
#                 {
#                     center: [48.72276909783789, 146.82874397675883],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_dcbfffb3dc6b57113968a170d08441b6);
#
#
#
#
#
#             var tile_layer_1350c469fca3cf5a4594b081ec704e0c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1350c469fca3cf5a4594b081ec704e0c.addTo(map_dcbfffb3dc6b57113968a170d08441b6);
#
#
#         function geo_json_bac357ce5a5187c27c047555bcd04e60_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1224&quot;: case &quot;1225&quot;: case &quot;1230&quot;: case &quot;1237&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#cccccc&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1226&quot;: case &quot;1227&quot;: case &quot;1232&quot;: case &quot;1233&quot;: case &quot;1234&quot;: case &quot;1239&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#7f99e6ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1228&quot;: case &quot;1235&quot;: case &quot;1241&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#d4dfffff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1229&quot;: case &quot;1231&quot;: case &quot;1236&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#aabcf3ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1238&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#2a53cdff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 default:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#0030c0ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#             }
#         }
#
#         function geo_json_bac357ce5a5187c27c047555bcd04e60_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_bac357ce5a5187c27c047555bcd04e60 = L.geoJson(null, {
#                 onEachFeature: geo_json_bac357ce5a5187c27c047555bcd04e60_onEachFeature,
#
#                 style: geo_json_bac357ce5a5187c27c047555bcd04e60_styler,
#             ...{
# }
#         });
#
#         function geo_json_bac357ce5a5187c27c047555bcd04e60_add (data) {
#             geo_json_bac357ce5a5187c27c047555bcd04e60
#                 .addData(data);
#         }
#             geo_json_bac357ce5a5187c27c047555bcd04e60_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[142.937117, 46.95497269999999], [142.9581561, 46.948637], [142.95395649999998, 46.94303059999999], [142.9591749, 46.93263459999999], [142.9441036, 46.91612810000001], [142.9611462, 46.8965369], [142.9605521, 46.8800433], [142.9494088, 46.8735177], [142.96425229999997, 46.8440349], [142.978448, 46.84525779999999], [142.97852979999996, 46.8401155], [142.96840710000004, 46

# %%
print_map(consumption_final[consumption_final['category'] == 'Маркетплейсы'],
        'Траты на маркетплейсы', VALUE_COL='consumption_percent')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91043ba4517d11458118388de459b43d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91043ba4517d11458118388de459b43d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91043ba4517d11458118388de459b43d = L.map(
#                 &quot;map_91043ba4517d11458118388de459b43d&quot;,
#                 {
#                     center: [48.72276909783789, 146.82874397675883],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_91043ba4517d11458118388de459b43d);
#
#
#
#
#
#             var tile_layer_17c7166ac3eb681d6958f967526e91fe = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_17c7166ac3eb681d6958f967526e91fe.addTo(map_91043ba4517d11458118388de459b43d);
#
#
#         function geo_json_286e6d5d92db8d7e753244e612dd25e3_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1224&quot;: case &quot;1225&quot;: case &quot;1230&quot;: case &quot;1237&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#cccccc&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1226&quot;: case &quot;1234&quot;: case &quot;1238&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#d4dfffff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1227&quot;: case &quot;1239&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#7f99e6ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1228&quot;: case &quot;1229&quot;: case &quot;1233&quot;: case &quot;1235&quot;: case &quot;1240&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#2a53cdff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1231&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#5576daff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 default:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#0030c0ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#             }
#         }
#
#         function geo_json_286e6d5d92db8d7e753244e612dd25e3_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_286e6d5d92db8d7e753244e612dd25e3 = L.geoJson(null, {
#                 onEachFeature: geo_json_286e6d5d92db8d7e753244e612dd25e3_onEachFeature,
#
#                 style: geo_json_286e6d5d92db8d7e753244e612dd25e3_styler,
#             ...{
# }
#         });
#
#         function geo_json_286e6d5d92db8d7e753244e612dd25e3_add (data) {
#             geo_json_286e6d5d92db8d7e753244e612dd25e3
#                 .addData(data);
#         }
#             geo_json_286e6d5d92db8d7e753244e612dd25e3_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[142.937117, 46.95497269999999], [142.9581561, 46.948637], [142.95395649999998, 46.94303059999999], [142.9591749, 46.93263459999999], [142.9441036, 46.91612810000001], [142.9611462, 46.8965369], [142.9605521, 46.8800433], [142.9494088, 46.8735177], [142.96425229999997, 46.8440349], [142.978448, 46.84525779999999], [142.97852979999996, 46.8401155], [142.96840710000004, 46.8392602], [142.96578829999999, 46.83099329999

# %%
print_map(consumption_final[consumption_final['category'] == 'Здоровье'],
        'Траты на здоровье', VALUE_COL='consumption_percent')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a2efbe32f343ad7bbd36663b3c507df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a2efbe32f343ad7bbd36663b3c507df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a2efbe32f343ad7bbd36663b3c507df = L.map(
#                 &quot;map_2a2efbe32f343ad7bbd36663b3c507df&quot;,
#                 {
#                     center: [48.72276909783789, 146.82874397675883],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_2a2efbe32f343ad7bbd36663b3c507df);
#
#
#
#
#
#             var tile_layer_fb8f119e8f9da7d6e05bb29ac7492ab8 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fb8f119e8f9da7d6e05bb29ac7492ab8.addTo(map_2a2efbe32f343ad7bbd36663b3c507df);
#
#
#         function geo_json_18731b0c93e6cfc9ca68a42d3e285fd5_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1224&quot;: case &quot;1225&quot;: case &quot;1230&quot;: case &quot;1237&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#cccccc&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1226&quot;: case &quot;1227&quot;: case &quot;1236&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#aabcf3ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1228&quot;: case &quot;1235&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#5576daff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1229&quot;: case &quot;1231&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#7f99e6ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1232&quot;: case &quot;1233&quot;: case &quot;1238&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#2a53cdff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1234&quot;: case &quot;1239&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#d4dfffff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 default:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#0030c0ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#             }
#         }
#
#         function geo_json_18731b0c93e6cfc9ca68a42d3e285fd5_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_18731b0c93e6cfc9ca68a42d3e285fd5 = L.geoJson(null, {
#                 onEachFeature: geo_json_18731b0c93e6cfc9ca68a42d3e285fd5_onEachFeature,
#
#                 style: geo_json_18731b0c93e6cfc9ca68a42d3e285fd5_styler,
#             ...{
# }
#         });
#
#         function geo_json_18731b0c93e6cfc9ca68a42d3e285fd5_add (data) {
#             geo_json_18731b0c93e6cfc9ca68a42d3e285fd5
#                 .addData(data);
#         }
#             geo_json_18731b0c93e6cfc9ca68a42d3e285fd5_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[142.937117, 46.95497269999999], [142.9581561, 46.948637], [142.95395649999998, 46.94303059999999], [142.9591749, 46.93263459999999], [142.9441036, 46.91612810000001], [142.9611462, 46.8965369], [142.9605521,

# %%
print_map(consumption_final[consumption_final['category'] == 'Продовольствие'],
        'Траты на продовольствие', VALUE_COL='consumption_percent')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e13a4297a35ea1c1fa95dae89f9ab92a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e13a4297a35ea1c1fa95dae89f9ab92a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e13a4297a35ea1c1fa95dae89f9ab92a = L.map(
#                 &quot;map_e13a4297a35ea1c1fa95dae89f9ab92a&quot;,
#                 {
#                     center: [48.72276909783789, 146.82874397675883],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_e13a4297a35ea1c1fa95dae89f9ab92a);
#
#
#
#
#
#             var tile_layer_ccda6323679890a02abed88337a4260d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ccda6323679890a02abed88337a4260d.addTo(map_e13a4297a35ea1c1fa95dae89f9ab92a);
#
#
#         function geo_json_90bf39ee425bee2896489f11b66d8419_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1224&quot;: case &quot;1225&quot;: case &quot;1230&quot;: case &quot;1237&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#cccccc&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1226&quot;: case &quot;1227&quot;: case &quot;1238&quot;: case &quot;1239&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#7f99e6ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1228&quot;: case &quot;1231&quot;: case &quot;1232&quot;: case &quot;1240&quot;: case &quot;1241&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#0030c0ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 case &quot;1229&quot;: case &quot;1233&quot;: case &quot;1235&quot;: case &quot;1236&quot;:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#2a53cdff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#                 default:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#d4dfffff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 0.7};
#             }
#         }
#
#         function geo_json_90bf39ee425bee2896489f11b66d8419_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_90bf39ee425bee2896489f11b66d8419 = L.geoJson(null, {
#                 onEachFeature: geo_json_90bf39ee425bee2896489f11b66d8419_onEachFeature,
#
#                 style: geo_json_90bf39ee425bee2896489f11b66d8419_styler,
#             ...{
# }
#         });
#
#         function geo_json_90bf39ee425bee2896489f11b66d8419_add (data) {
#             geo_json_90bf39ee425bee2896489f11b66d8419
#                 .addData(data);
#         }
#             geo_json_90bf39ee425bee2896489f11b66d8419_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[142.937117, 46.95497269999999], [142.9581561, 46.948637], [142.95395649999998, 46.94303059999999], [142.9591749, 46.93263459999999], [142.9441036, 46.91612810000001], [142.9611462, 46.8965369], [142.9605521, 46.8800433], [142.9494088, 46.8735177], [142.96425229999997, 46.8440349], [142.978448, 46.84525779999999], [142.97852979999996, 46.8401155], [142.96840710000004, 46.8392602], [142.96578829999999, 46.830993299999996], [142.95560369999998, 46.82773660000001], [142.9555243, 46.825250399999994], [142.9430495, 46.8253201], [142.9237271, 46.8324116], [142.
